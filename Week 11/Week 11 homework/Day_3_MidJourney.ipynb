# %%
pip install replicate
# Out:
# Collecting replicate
#   Downloading replicate-0.15.7-py3-none-any.whl (27 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from replicate) (23.2)
# Requirement already satisfied: pydantic>1 in /usr/local/lib/python3.10/dist-packages (from replicate) (1.10.13)
# Collecting httpx<1,>=0.21.0 (from replicate)
#   Downloading httpx-0.25.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.21.0->replicate) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.21.0->replicate) (2023.7.22)
# Collecting httpcore (from httpx<1,>=0.21.0->replicate)
#   Downloading httpcore-1.0.1-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.21.0->replicate) (3.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.21.0->replicate) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>1->replicate) (4.5.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.21.0->replicate) (1.1.3)
# Collecting h11<0.15,>=0.13 (from httpcore->httpx<1,>=0.21.0->replicate)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.6 MB/s eta 0:00:00
# Installing collected packages: h11, httpcore, httpx, replicate
# Successfully installed h11-0.14.0 httpcore-1.0.1 httpx-0.25.1 replicate-0.15.7

# %%
import json
import time
import requests

q = input("Enter your picture request : ")
# Out:
# Enter your picture request : koala

# %%
body = json.dumps(
  {
    "version": "db21e45d3f7023abc2a46ee38a23973f6dce16bb082a930b0c49861f96d1e5bf",
     "input": { "prompt": q }
  }
)
headers = {
  'Authorization': 'Token r8_9cid7ntGfUtiSAlruikwktPqWim2BWJ3u0tz3',
  'Content-Type': 'application/json'
}

# %%
output = requests.post('https://api.replicate.com/v1/predictions',data=body,headers=headers)
time.sleep(10)
print(output.json())
# Out:
# {'id': 'yejy36dboyrhfprymn7f3r6hom', 'version': 'db21e45d3f7023abc2a46ee38a23973f6dce16bb082a930b0c49861f96d1e5bf', 'input': {'prompt': 'koala'}, 'logs': '', 'error': None, 'status': 'starting', 'created_at': '2023-11-04T12:30:52.620002402Z', 'urls': {'cancel': 'https://api.replicate.com/v1/predictions/yejy36dboyrhfprymn7f3r6hom/cancel', 'get': 'https://api.replicate.com/v1/predictions/yejy36dboyrhfprymn7f3r6hom'}}

# %%
output
# Out:
# <Response [201]>

# %%
get_url = output.json()['urls']['get']
print(get_url)
get_result = requests.post(get_url,headers=headers).json()['output']
print(get_result)
# Out:
# https://api.replicate.com/v1/predictions/yejy36dboyrhfprymn7f3r6hom
# ['https://replicate.delivery/pbxt/2g1SXFKQeu3BYSyytjcCEKT0NdnPHcX37Fusweow1qmfb9pjA/out-0.png']

# %%
#print image
from PIL import Image
image = Image.open(requests.get(get_result[0], stream=True).raw)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=768x768>
